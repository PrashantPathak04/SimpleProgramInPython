# %% [markdown]
# <a href="https://colab.research.google.com/github/PrashantPathak04/SimpleProgramInPython/blob/main/checkCuda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np

tensor = torch.rand(3, 4)
if torch.cuda.is_available():
  tensor = tensor.to('cuda')
  print(f"Shape of tensor: {tensor.shape}")
  print(f"Datatype of tensor: {tensor.dtype}")
  print(f"Device tensor is stored on: {tensor.device}")
# Addition
#print(a + b)

# Dot product
#print(torch.dot(a, b))

# Reshape
#print(a.view(3, 1))
# Out:
# Shape of tensor: torch.Size([3, 4])
# Datatype of tensor: torch.float32
# Device tensor is stored on: cuda:0

# %% [markdown]
# # New section
