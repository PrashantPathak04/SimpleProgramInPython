# %% [markdown]
# <a href="https://colab.research.google.com/github/PrashantPathak04/SimpleProgramInPython/blob/main/texttovideo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # CLIP Libraray
#python
# !git clone https://github.com/openai/CLIP.git
#
#CLIP (Contrastive Language-Image Pretraining), Predict the most relevant text snippet given an image
# !git clone https://github.com/CompVis/taming-transformers.git
# Out:
# Cloning into 'CLIP'...
# remote: Enumerating objects: 256, done.
# remote: Total 256 (delta 0), reused 0 (delta 0), pack-reused 256 (from 1)
# Receiving objects: 100% (256/256), 8.87 MiB | 35.91 MiB/s, done.
# Resolving deltas: 100% (136/136), done.
# Cloning into 'taming-transformers'...
# remote: Enumerating objects: 1342, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1342 (delta 0), reused 0 (delta 0), pack-reused 1341 (from 2)
# Receiving objects: 100% (1342/1342), 409.77 MiB | 47.36 MiB/s, done.
# Resolving deltas: 100% (282/282), done.

# %%
# !pip install --no-deps  ftfy regex tqdm
# !pip install omegaconf==2.0.0
# !pip install pytorch-lightning==1.0.8
# !pip uninstall torchtest --yes
# !pip install einops
# Out:
# ...
#   Using cached omegaconf-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Attempting uninstall: omegaconf
#     Found existing installation: omegaconf 2.3.0
#     Uninstalling omegaconf-2.3.0:
#       Successfully uninstalled omegaconf-2.3.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 19.3 MB/s eta 0:00:00
# ...
# WARNING: Skipping torchtest as it is not installed.
# ...

# %%
import numpy as np
import torch,os, imageio, pdb, math
import torchvision
import torchvision.transforms as T
import torchvision.transforms.functional as TF
import PIL
import matplotlib.pyplot as plt
import yaml
from omegaconf import OmegaConf
from CLIP import clip

# %%
def show_from_tensor(tensor):
 img=tensor.clone()
 img= img.mul(255).byte()
 img = img.cpu().numpy().transpose((1,2,0))
 plt.figure(figsize=(10,7))
 plt.axis('off')
 plt.imshow(img)
 plt.show()

def norm_data(data):
  return (data.clip(-1,1)+1)/2

learning_rate= .5
batch_size = 1
wd = .1
noise_factor = .1
total_iter = 100
im_shape = [255,400,3]
size1, size2, channels= im_shape

# %%
clipmodel, _ =clip.load('ViT-B/32',jit = False)
clipmodel.eval()
print(clip.available_models())

print("clip model visual resulation", clipmodel.visual.input_resolution)

device =torch.device("cuda:0")
torch.cuda.empty_cache()
# Out:
# 100%|████████████████████████████████████████| 338M/338M [00:02<00:00, 151MiB/s]
# ['RN50', 'RN101', 'RN50x4', 'RN50x16', 'RN50x64', 'ViT-B/32', 'ViT-B/16', 'ViT-L/14', 'ViT-L/14@336px']
# clip model visual resulation 224
